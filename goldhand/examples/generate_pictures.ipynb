# %%
from goldhand import *
tw=Tw()
ticker = "BTC-USD"
t = GoldHand(ticker)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 'NoneType' object does not support item assignment

# %%
p = t.plotly_last_year(tw.get_plotly_title(ticker))
p.write_image("../../img/crypto_%s.png"%ticker)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/envs/python311/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'local'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 p = t.plotly_last_year(tw.get_plotly_title(ticker))
#       2 p.write_image("../../img/crypto_%s.png"%ticker)
#
# File ~/GitHub/goldhand/goldhand/stocks.py:207, in GoldHand.plotly_last_year(self, plot_title, plot_height, ndays, ad_local_min_max)
#     205 fig = go.Figure(data=go.Ohlc(x=tdf['date'], open=tdf['open'], high=tdf['high'], low=tdf['low'],close=tdf['close']))
#     206 if ad_local_min_max:
# --> 207     for index, row in tdf[tdf['local']!=''].iterrows():
#     208         direction = row['local']
#     209         tdate = row['date']
#
# File ~/opt/miniconda3/envs/python311/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/opt/miniconda3/envs/python311/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'local'

# %%
p = t.plot_goldhand_line(tw.get_plotly_title(ticker))
p.show()
p.write_image("../../img/goldhand_line_%s.png"%ticker)
# Out:
# <div>                            <div id="a209d1c2-4b23-4628-b0c9-5ef4ba1f3e9d" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a209d1c2-4b23-4628-b0c9-5ef4ba1f3e9d")) {                    Plotly.newPlot(                        "a209d1c2-4b23-4628-b0c9-5ef4ba1f3e9d",                        [{"close":[46737.48046875,46612.6328125,48896.72265625,47665.42578125,46202.14453125,46848.77734375,46707.015625,46880.27734375,48936.61328125,48628.51171875,50784.5390625,50822.1953125,50429.859375,50809.515625,50640.41796875,47588.85546875,46444.7109375,47178.125,46306.4453125,47686.8125,47345.21875,46458.1171875,45897.57421875,43569.00390625,43160.9296875,41557.90234375,41733.94140625,41911.6015625,41821.26171875,42735.85546875,43949.1015625,42591.5703125,43099.69921875,43177.3984375,43113.87890625,42250.55078125,42375.6328125,41744.328125,40680.41796875,36457.31640625,35030.25,36276.8046875,36654.328125,36954.00390625,36852.12109375,37138.234375,37784.33203125,38138.1796875,37917.6015625,38483.125,38743.2734375,36952.984375,37154.6015625,41500.875,41441.1640625,42412.43359375,43840.28515625,44118.4453125,44338.796875,43565.11328125,42407.9375,42244.46875,42197.515625,42586.91796875,44575.203125,43961.859375,40538.01171875,40030.9765625,40122.15625,38431.37890625,37075.28125,38286.02734375,37296.5703125,38332.609375,39214.21875,39105.1484375,37709.78515625,43193.234375,44354.63671875,43924.1171875,42451.7890625,39137.60546875,39400.5859375,38419.984375,38062.0390625,38737.26953125,41982.92578125,39437.4609375,38794.97265625,38904.01171875,37849.6640625,39666.75390625,39338.78515625,41143.9296875,40951.37890625,41801.15625,42190.65234375,41247.82421875,41077.99609375,42358.80859375,42892.95703125,43960.93359375,44348.73046875,44500.828125,46820.4921875,47128.00390625,47465.73046875,47062.6640625,45538.67578125,46281.64453125,45868.94921875,46453.56640625,46622.67578125,45555.9921875,43206.73828125,43503.84765625,42287.6640625,42782.13671875,42207.671875,39521.90234375,40127.18359375,41166.73046875,39935.515625,40553.46484375,40424.484375,39716.953125,40826.21484375,41502.75,41374.37890625,40527.36328125,39740.3203125,39486.73046875,39469.29296875,40458.30859375,38117.4609375,39241.12109375,39773.828125,38609.82421875,37714.875,38469.09375,38529.328125,37750.453125,39698.37109375,36575.140625,36040.921875,35501.953125,34059.265625,30296.953125,31022.90625,28936.35546875,29047.751953125,29283.103515625,30101.265625,31305.11328125,29862.91796875,30425.857421875,28720.271484375,30314.333984375,29200.740234375,29432.2265625,30323.72265625,29098.91015625,29655.5859375,29562.361328125,29267.224609375,28627.57421875,28814.900390625,29445.95703125,31726.390625,31792.310546875,29799.080078125,30467.48828125,29704.390625,29832.9140625,29906.662109375,31370.671875,31155.478515625,30214.35546875,30111.998046875,29083.8046875,28360.810546875,26762.6484375,22487.388671875,22206.79296875,22572.83984375,20381.650390625,20471.482421875,19017.642578125,20553.271484375,20599.537109375,20710.59765625,19987.029296875,21085.876953125,21231.65625,21502.337890625,21027.294921875,20735.478515625,20280.634765625,20104.0234375,19784.7265625,19269.3671875,19242.255859375,19297.076171875,20231.26171875,20190.115234375,20548.24609375,21637.587890625,21731.1171875,21592.20703125,20860.44921875,19970.556640625,19323.9140625,20212.07421875,20569.919921875,20836.328125,21190.31640625,20779.34375,22485.689453125,23389.43359375,23231.732421875,23164.62890625,22714.978515625,22465.478515625,22609.1640625,21361.701171875,21239.75390625,22930.548828125,23843.88671875,23804.6328125,23656.20703125,23336.896484375,23314.19921875,22978.1171875,22846.5078125,22630.95703125,23289.314453125,22961.279296875,23175.890625,23809.486328125,23164.318359375, ...

# %%
data = t.df
backtest = Backtest( data, goldhand_line_strategy,  plot_title=tw.get_plotly_title(ticker), 
                     buy_at = 'gold', sell_at = 'blue')
backtest.summarize_strategy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 data = t.df
# ----> 2 backtest = Backtest( data, goldhand_line_strategy,  plot_title=tw.get_plotly_title(ticker),
#       3                      buy_at = 'gold', sell_at = 'blue')
#       4 backtest.summarize_strategy()
#
# File ~/GitHub/goldhand/goldhand/backtest.py:22, in Backtest.__init__(self, data, strategy_function, plot_title, **kwargs)
#      20 self.strategy_function = strategy_function
#      21 self.additional_params = kwargs
# ---> 22 self.add_trades()
#      23 self.summary_of_trades()
#
# File ~/GitHub/goldhand/goldhand/backtest.py:30, in Backtest.add_trades(self)
#      26 def add_trades(self):
#      27     """
#      28     Calculate the trades using the strategy function and the data provided
#      29     """
# ---> 30     self.trades = self.strategy_function(self.data, **self.additional_params)
#      31     self.trades['ticker'] = self.data['ticker'].iloc[0]
#      33     # order columns
#
# File ~/GitHub/goldhand/goldhand/strategy_goldhand_line.py:101, in goldhand_line_strategy(data, buy_at, sell_at)
#      98     temp_trade['sell_date'] = data['date'][i]
#     100     temp_trade['result'] = temp_trade['sell_price'] / temp_trade['buy_price']
# --> 101     temp_trade['days_in_trade'] = (temp_trade['sell_date'] - temp_trade['buy_date']).days
#     102     all_trades.append(temp_trade)
#     104 res_df = pd.DataFrame(all_trades)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'datetime.date'

# %%
p = show_indicator_goldhand_line_strategy(ticker = ticker, plot_title=tw.get_plotly_title(ticker), 
                                          buy_at='gold', sell_at='blue',  add_strategy_summary=True)
p.write_image("../../img/goldhand_line_strategy_%s.png"%ticker)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 p = show_indicator_goldhand_line_strategy(ticker = ticker, plot_title=tw.get_plotly_title(ticker),
#       2                                           buy_at='gold', sell_at='blue',  add_strategy_summary=True)
#       3 p.write_image("../../img/goldhand_line_strategy_%s.png"%ticker)
#
# File ~/GitHub/goldhand/goldhand/strategy_goldhand_line.py:169, in show_indicator_goldhand_line_strategy(ticker, plot_title, buy_at, sell_at, ndays, plot_height, add_strategy_summary)
#     164 data['group'] = (data['color_change']).cumsum()
#     166 ##### data preparation end
#     167
#     168 ##### backtest
# --> 169 backtest = Backtest( data, goldhand_line_strategy, plot_title =plot_title, buy_at= buy_at, sell_at=sell_at)
#     170 trades =backtest.trades
#     172 if ndays!=0:
#
# File ~/GitHub/goldhand/goldhand/backtest.py:22, in Backtest.__init__(self, data, strategy_function, plot_title, **kwargs)
#      20 self.strategy_function = strategy_function
#      21 self.additional_params = kwargs
# ---> 22 self.add_trades()
#      23 self.summary_of_trades()
#
# File ~/GitHub/goldhand/goldhand/backtest.py:30, in Backtest.add_trades(self)
#      26 def add_trades(self):
#      27     """
#      28     Calculate the trades using the strategy function and the data provided
#      29     """
# ---> 30     self.trades = self.strategy_function(self.data, **self.additional_params)
#      31     self.trades['ticker'] = self.data['ticker'].iloc[0]
#      33     # order columns
#
# File ~/GitHub/goldhand/goldhand/strategy_goldhand_line.py:101, in goldhand_line_strategy(data, buy_at, sell_at)
#      98     temp_trade['sell_date'] = data['date'][i]
#     100     temp_trade['result'] = temp_trade['sell_price'] / temp_trade['buy_price']
# --> 101     temp_trade['days_in_trade'] = (temp_trade['sell_date'] - temp_trade['buy_date']).days
#     102     all_trades.append(temp_trade)
#     104 res_df = pd.DataFrame(all_trades)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'datetime.date'
